# %%
#d['c_weight'] = d['weight'] - d['weight'].mean()
#d['s_weight'] = d['c_weight']/d['weight'].std()
#d.head()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import arviz as az
from cmdstanpy import CmdStanModel

X = pd.read_csv("./project/data_analytics/processed_data_standarized_only.csv")
y = X["default"]
X = X.drop(columns=['default'])
N, K = X.shape

print(X.shape)
cols = list(X.columns)
print(cols)
# Out:
# (5000, 5)
# ['s_int_rate', 's_dti', 's_loan_amnt', 's_installment', 's_annual_inc']

# %%
plt.hist(X[cols[0]], bins=30, edgecolor='k')
plt.title(cols[0])
plt.xlabel("P(default)")
plt.ylabel("Liczba obserwacji")
plt.show()

plt.hist(X[cols[1]], bins=30, edgecolor='k')
plt.title(cols[1])
plt.xlabel("P(default)")
plt.ylabel("Liczba obserwacji")
plt.show()

plt.hist(X[cols[2]], bins=30, edgecolor='k')
plt.title(cols[2])
plt.xlabel("P(default)")
plt.ylabel("Liczba obserwacji")
plt.show()

plt.hist(X[cols[3]], bins=30, edgecolor='k')
plt.title(cols[3])
plt.xlabel("P(default)")
plt.ylabel("Liczba obserwacji")
plt.show()

plt.hist(X[cols[4]], bins=30, edgecolor='k')
plt.title(cols[4])
plt.xlabel("P(default)")
plt.ylabel("Liczba obserwacji")
plt.show()


plt.hist(y.values, bins=30, edgecolor='k')
plt.title("default")
plt.xlabel("P(default)")
plt.ylabel("Liczba obserwacji")
plt.show()

rng = np.random.default_rng()
a, b, size = 0.5, 0.5, 10000
sample = rng.beta(a=a, b=b, size=size)
plt.hist(sample, bins=30, edgecolor='k')
plt.title("beta")
plt.xlabel("P(default)")
plt.ylabel("Liczba obserwacji")
plt.show()
